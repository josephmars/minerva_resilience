# %% [markdown]
# # Youtube DATA API

# %%
# Scrape Or Download Comments Using Python Through The Youtube Data API
# Watch the youtube video for explaination
# https://youtu.be/B9uCX2s7y7A

api_key = "AIzaSyBAYACoW7OPcMPUymmAze2VLrf8ddGR4rE" # Replace this dummy api key with your own.

from apiclient.discovery import build
youtube = build('youtube', 'v3', developerKey=api_key)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       1 # Scrape Or Download Comments Using Python Through The Youtube Data API
#       2 # Watch the youtube video for explaination
#       3 # https://youtu.be/B9uCX2s7y7A
#       5 api_key = "AIzaSyBAYACoW7OPcMPUymmAze2VLrf8ddGR4rE" # Replace this dummy api key with your own.
# ----> 7 from apiclient.discovery import build
#       8 youtube = build('youtube', 'v3', developerKey=api_key)
#
# ModuleNotFoundError: No module named 'apiclient.discovery'

# %%
import pandas as pd

ID = "FlkLANJmpPw" # Replace this YouTube video ID with your own.

box = [['Name', 'Comment', 'Time', 'Likes', 'Reply Count']]


def scrape_comments_with_replies():
    data = youtube.commentThreads().list(part='snippet', videoId=ID, maxResults='100', textFormat="plainText").execute()

    for i in data["items"]:

        name = i["snippet"]['topLevelComment']["snippet"]["authorDisplayName"]
        comment = i["snippet"]['topLevelComment']["snippet"]["textDisplay"]
        published_at = i["snippet"]['topLevelComment']["snippet"]['publishedAt']
        likes = i["snippet"]['topLevelComment']["snippet"]['likeCount']
        replies = i["snippet"]['totalReplyCount']

        box.append([name, comment, published_at, likes, replies])

        totalReplyCount = i["snippet"]['totalReplyCount']

        if totalReplyCount > 0:

            parent = i["snippet"]['topLevelComment']["id"]

            data2 = youtube.comments().list(part='snippet', maxResults='100', parentId=parent,
                                            textFormat="plainText").execute()

            for i in data2["items"]:
                name = i["snippet"]["authorDisplayName"]
                comment = i["snippet"]["textDisplay"]
                published_at = i["snippet"]['publishedAt']
                likes = i["snippet"]['likeCount']
                replies = ""

                box.append([name, comment, published_at, likes, replies])

    while ("nextPageToken" in data):

        data = youtube.commentThreads().list(part='snippet', videoId=ID, pageToken=data["nextPageToken"],
                                             maxResults='100', textFormat="plainText").execute()

        for i in data["items"]:
            name = i["snippet"]['topLevelComment']["snippet"]["authorDisplayName"]
            comment = i["snippet"]['topLevelComment']["snippet"]["textDisplay"]
            published_at = i["snippet"]['topLevelComment']["snippet"]['publishedAt']
            likes = i["snippet"]['topLevelComment']["snippet"]['likeCount']
            replies = i["snippet"]['totalReplyCount']

            box.append([name, comment, published_at, likes, replies])

            totalReplyCount = i["snippet"]['totalReplyCount']

            if totalReplyCount > 0:

                parent = i["snippet"]['topLevelComment']["id"]

                data2 = youtube.comments().list(part='snippet', maxResults='100', parentId=parent,
                                                textFormat="plainText").execute()

                for i in data2["items"]:
                    name = i["snippet"]["authorDisplayName"]
                    comment = i["snippet"]["textDisplay"]
                    published_at = i["snippet"]['publishedAt']
                    likes = i["snippet"]['likeCount']
                    replies = ''

                    box.append([name, comment, published_at, likes, replies])

    df = pd.DataFrame({'Name': [i[0] for i in box], 'Comment': [i[1] for i in box], 'Time': [i[2] for i in box],
                       'Likes': [i[3] for i in box], 'Reply Count': [i[4] for i in box]})

    df.to_csv('youtube-comments.csv', index=False, header=False)

    return "Successful! Check the CSV file that you have just created."


scrape_comments_with_replies()

# %% [markdown]
# # 1. NewsAPI.org

# %%
key = "9452eb50fe144175903e48875e459fe0"

# %%
from newsapi import NewsApiClient

# Init
newsapi = NewsApiClient(api_key='9452eb50fe144175903e48875e459fe0')

# %%
# # /v2/top-headlines
# top_headlines = newsapi.get_top_headlines(q='bitcoin',
#                                           sources='bbc-news,the-verge',
#                                           category='business',
#                                           language='en',
#                                           country='us')

# /v2/everything
all_articles = newsapi.get_everything(q='migrants',
                                      sources='bbc-news',
                                      to='2024-03-16',
                                      language='en',
                                      sort_by='relevancy',
                                      page=2)

# /v2/top-headlines/sources
sources = newsapi.get_sources()

# %%
sources
# Out:
# {'status': 'ok',
#  'sources': [{'id': 'abc-news',
#    'name': 'ABC News',
#    'description': 'Your trusted source for breaking news, analysis, exclusive interviews, headlines, and videos at ABCNews.com.',
#    'url': 'https://abcnews.go.com',
#    'category': 'general',
#    'language': 'en',
#    'country': 'us'},
#   {'id': 'abc-news-au',
#    'name': 'ABC News (AU)',
#    'description': "Australia's most trusted source of local, national and world news. Comprehensive, independent, in-depth analysis, the latest business, sport, weather and more.",
#    'url': 'https://www.abc.net.au/news',
#    'category': 'general',
#    'language': 'en',
#    'country': 'au'},
#   {'id': 'aftenposten',
#    'name': 'Aftenposten',
#    'description': 'Norges ledende nettavis med alltid oppdaterte nyheter innenfor innenriks, utenriks, sport og kultur.',
#    'url': 'https://www.aftenposten.no',
#    'category': 'general',
#    'language': 'no',
#    'country': 'no'},
# ...

# %%
# Run a GET request to the specified URL
import requests
url = "https://newsapi.org/v2/everything?q=migrants&apiKey=9452eb50fe144175903e48875e459fe0"
response = requests.get(url)

# %%
response.json()['articles'][0]
# Out:
# {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#  'author': 'https://www.facebook.com/bbcnews',
#  'title': "Home Office launches 'stop the boats' ad campaign in Vietnam",
#  'description': 'The government says an increasing proportion of small boat crossings are made by Vietnamese nationals.',
#  'url': 'https://www.bbc.co.uk/news/uk-politics-68653368',
#  'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/69A0/production/_133004072_smallboatskent1.png',
#  'publishedAt': '2024-03-25T05:55:13Z',
#  'content': 'The Home Office has launched a social media advert campaign targeting Vietnamese nationals to deter them from illegally migrating to the UK.\r\nThe government says the adverts will set out the risks of… [+2475 chars]'}

# %% [markdown]
# # 2. SerpAPI

# %%
serp_key = "d157fc3d96ed64d10a5f83072f9e283adc9e752a7d4577bac9b2d8eba6b1697e"

# %%
url = "https://serpapi.com/search/?engine=google_news&q=migrants&location=United%20States&hl=en&gl=us&api_key=d157fc3d96ed64d10a5f83072f9e283adc9e752a7d4577bac9b2d8eba6b1697e"
response = requests.get(url)

# %%
response.json()
# Out:
# {'search_metadata': {'id': '66200efbada54bf4e4c5b5de',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/535a83b0c7853b22/66200efbada54bf4e4c5b5de.json',
#   'created_at': '2024-04-17 18:03:39 UTC',
#   'processed_at': '2024-04-17 18:03:39 UTC',
#   'google_news_url': 'https://news.google.com/search?q=migrants&gl=US',
#   'raw_html_file': 'https://serpapi.com/searches/535a83b0c7853b22/66200efbada54bf4e4c5b5de.html',
#   'total_time_taken': 7.03},
#  'search_parameters': {'engine': 'google_news', 'gl': 'us', 'q': 'migrants'},
#  'news_results': [{'position': 1,
#    'title': 'Black immigrants gather at NYC immigration hearing',
#    'stories': [{'position': 1,
#      'title': "Migrants rally at NYC's City Hall, want officials to make it easier for them to work",
#      'source': {'name': 'CBS New York',
#       'icon': 'https://lh3.googleusercontent.com/QOPT9_eGKyxfeHZbvRptZwUMtadixIdybhDWKk4hiXX8IL67pr9a8idpn197v-HKiev5sZ9oNZw',
# ...

# %%
newsdata_io_url = "https://newsdata.io/api/1/news?&q=pizza&language=en&country=us&apiKey=pub_42205699940101d61679b797df25a7109774d"
newsdata_io_response = requests.get(newsdata_io_url)

# %%
newsdata_io_response.json()['results']
# Out:
# [{'article_id': '4a78ebc71447a7494e8e1941d6bcecc6',
#   'title': 'Obituary: Ruth E. Bendlak',
#   'link': 'https://www.pressherald.com/2024/04/17/obituaryruth-e-bendlak/',
#   'keywords': ['obituaries', 'times record', 'times record obituaries'],
#   'creator': None,
#   'video_url': None,
#   'description': 'BOWDOIN - Ruth E. Bendlak, 61, passed away at the Androscoggin Hospice House in Auburn on April 13, 2024. She was ...',
#   'content': 'ONLY AVAILABLE IN PAID PLANS',
#   'pubDate': '2024-04-17 05:01:01',
#   'image_url': None,
#   'source_id': 'pressherald',
#   'source_priority': 5727,
#   'source_url': 'https://www.pressherald.com',
#   'source_icon': 'https://i.bytvi.com/domain_icons/pressherald.png',
#   'language': 'english',
#   'country': ['united states of america'],
#   'category': ['other'],
#   'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#   'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
# ...

# %% [markdown]
# # GNews (Brian)

# %%
import pandas as pd
import json
from gnews import GNews

# %%
# Read data from txt file
with open('../data/CrisisLexRec.txt', 'r') as file:
    lexicon = file.read().splitlines()

# %%
total_news = []
print(f"Searching for {len(lexicon)} keywords")
for keyword in lexicon:
    
    google_news = GNews()
    google_news.start_date = (2020, 1, 1) # Search from 1st Jan 2020
    google_news.end_date = (2020, 3, 1) # Search until 1st March 2020
    news = google_news.get_news(keyword)

    total_news += news
    print(f"{len(news)} results for keyword: {keyword}")
# Out:
# Searching for 380 keywords
# 40 results for keyword: flood crisis
# 100 results for keyword: victims
# 99 results for keyword: flood victims
# 47 results for keyword: flood powerful
# 56 results for keyword: powerful storms
# 5 results for keyword: hoisted flood
# 53 results for keyword: storms amazing
# 100 results for keyword: explosion
# 44 results for keyword: amazing rescue
# 93 results for keyword: rescue women
# 67 results for keyword: flood cost
# 46 results for keyword: counts flood
# 99 results for keyword: toll rises
# 47 results for keyword: braces river
# 38 results for keyword: river peaks
# 47 results for keyword: crisis deepens
# 100 results for keyword: prayers
# 33 results for keyword: thoughts prayers
# 64 results for keyword: affected tornado
# 100 results for keyword: affected
# 100 results for keyword: death toll
# 46 results for keyword: tornado relief
# 100 results for keyword: photos flood
# 50 results for keyword: water rises
# 100 results for keyword: toll
# ...

# %%
# Save in json file
with open('../data/news/medata-news.json', 'w') as f:
    json.dump(total_news, f, indent=4)

# %% [markdown]
# # Content

# %%
import time

# %%
start_time = time.time()
content = []
for new in total_news:
    article = google_news.get_full_article(new['url'])
    if article is not None:
        content.append({'title': article.title, 'author': article.authors, 'text': article.text, 'images': article.images, 'url': new['url'], 'download': 1})
    else:
        content.append({'title': None, 'author': None, 'text': None, 'images': None, 'url': new['url'], 'download': 0})

print(f"Time taken: {time.time() - start_time}")
print("Time per article: ", (time.time() - start_time) / len(content))
# Out:
# An error occurred while fetching the article: Article `download()` failed with 503 Server Error: Service Unavailable for url: https://news.google.com/rss/articles/CBMiV2h0dHBzOi8vcHVibGljaW50ZWdyaXR5Lm9yZy9lbnZpcm9ubWVudC9mbG9vZC1pbnN1cmFuY2UtY2xpbWF0ZS1jaGFuZ2Utcmlzay1pbmVxdWFsaXR5L9IBAA?oc=5&hl=en-US&gl=US&ceid=US:en on URL https://news.google.com/rss/articles/CBMiV2h0dHBzOi8vcHVibGljaW50ZWdyaXR5Lm9yZy9lbnZpcm9ubWVudC9mbG9vZC1pbnN1cmFuY2UtY2xpbWF0ZS1jaGFuZ2Utcmlzay1pbmVxdWFsaXR5L9IBAA?oc=5&hl=en-US&gl=US&ceid=US:en
# ...

# %%
# Export content to json file
with open('../data/news/news-content.json', 'w') as f:
    json.dump(content, f, indent=4)
