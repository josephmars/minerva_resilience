# %%
import pandas as pd

# %%
# import data from xlsx files from 2017 to 2023 under data/GSCI/
for year in range(2017, 2024):
    df = pd.read_excel(f'../data/GSCI/{year}.xlsx')

# %%
df
# Out:
#      Unnamed: 0                                         Unnamed: 1  \
# 0           NaN  The Global Sustainable Competitiveness Index  ...
# 1           NaN                                            Country
# 2           NaN                                            Country
# 3           NaN                                             Sweden
# 4           NaN                                            Finland
# ..          ...                                                ...
# 183         NaN                                            Eritrea
# 184         NaN                                                NaN
# 185         NaN                                                Max
# 186         NaN                                            Average
# 187         NaN                                                Min
#
#                       Unnamed: 2 Unnamed: 3       Unnamed: 4 Unnamed: 5  \
# 0                            NaN        NaN              NaN        NaN
# ...
